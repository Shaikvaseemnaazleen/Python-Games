# %% [markdown]
# # COVID - 19 DATA ANALYSIS

# %% [markdown]
# ## Import the modules required

# %%
import numpy as np
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt

print("Imported the modules required..")
# Out:
# Imported the modules required..

# %% [markdown]
# ## Import the  COVID - 19 data set

# %%
# our dataset is a csv file  -> covid19_Confirmed_dataset.csv
# we use read_csv() method to read the contents of the csv file and convert to df

corona_dataset_csv = pd.read_csv("covid19_Confirmed_dataset.csv")

# to view the top 10 lines of dataset -> use head

corona_dataset_csv.head(10)
# Out:
#                  Province/State       Country/Region      Lat      Long  \
# 0                           NaN          Afghanistan  33.0000   65.0000
# 1                           NaN              Albania  41.1533   20.1683
# 2                           NaN              Algeria  28.0339    1.6596
# 3                           NaN              Andorra  42.5063    1.5218
# 4                           NaN               Angola -11.2027   17.8739
# 5                           NaN  Antigua and Barbuda  17.0608  -61.7964
# 6                           NaN            Argentina -38.4161  -63.6167
# 7                           NaN              Armenia  40.0691   45.0382
# 8  Australian Capital Territory            Australia -35.4735  149.0124
# 9               New South Wales            Australia -33.8688  151.2093
#
#    1/22/20  1/23/20  1/24/20  1/25/20  1/26/20  1/27/20  ...  4/21/20  \
# 0        0        0        0        0        0        0  ...     1092
# ...

# %%
# check the dimensions of dataset -> shape

corona_dataset_csv.shape
# Out:
# (266, 104)

# %% [markdown]
# ## Delete the useless columns

# %%
# we dont require the longitudes and latitudes for our analysis -> use drop

corona_dataset_csv.drop(['Lat', 'Long'], axis = 1, inplace = True)

# view the changes

corona_dataset_csv.head(10)
# Out:
#                  Province/State       Country/Region  1/22/20  1/23/20  \
# 0                           NaN          Afghanistan        0        0
# 1                           NaN              Albania        0        0
# 2                           NaN              Algeria        0        0
# 3                           NaN              Andorra        0        0
# 4                           NaN               Angola        0        0
# 5                           NaN  Antigua and Barbuda        0        0
# 6                           NaN            Argentina        0        0
# 7                           NaN              Armenia        0        0
# 8  Australian Capital Territory            Australia        0        0
# 9               New South Wales            Australia        0        0
#
#    1/24/20  1/25/20  1/26/20  1/27/20  1/28/20  1/29/20  ...  4/21/20  \
# 0        0        0        0        0        0        0  ...     1092
# ...

# %% [markdown]
# ## Aggregating the rows by country

# %%
corona_dataset_aggregated = corona_dataset_csv.groupby("Country/Region").sum()

# %%
# view the changes made

corona_dataset_aggregated.head(10)
# Out:
#                      1/22/20  1/23/20  1/24/20  1/25/20  1/26/20  1/27/20  \
# Country/Region
# Afghanistan                0        0        0        0        0        0
# Albania                    0        0        0        0        0        0
# Algeria                    0        0        0        0        0        0
# Andorra                    0        0        0        0        0        0
# Angola                     0        0        0        0        0        0
# Antigua and Barbuda        0        0        0        0        0        0
# Argentina                  0        0        0        0        0        0
# Armenia                    0        0        0        0        0        0
# Australia                  0        0        0        0        4        5
# Austria                    0        0        0        0        0        0
#
#                      1/28/20  1/29/20  1/30/20  1/31/20  ...  4/21/20  \
# Country/Region                                           ...
# ...

# %%
# check the shape of our dataframe

corona_dataset_aggregated.shape
# Out:
# (187, 100)

# %% [markdown]
# # Visualizing the data related to the country

# %%
# for example India
# we use loc method to get the dataframe of the country and plot it

corona_dataset_aggregated.loc['India']
corona_dataset_aggregated.loc['India'].plot()

# %%
# for exmaple America

corona_dataset_aggregated.loc['Australia']
corona_dataset_aggregated.loc['Australia'].plot()

# %%
# to visualize diffeent countries data in a same graph

corona_dataset_aggregated.loc['India'].plot()
corona_dataset_aggregated.loc['Australia'].plot()
corona_dataset_aggregated.loc['Italy'].plot()

plt.legend()

# %%
# for exmaple china

corona_dataset_aggregated.loc['China']
corona_dataset_aggregated.loc['China'].plot()

# %%
# Lets analyse the first three days of the corona virus

corona_dataset_aggregated.loc['China'][:3].plot()

# %% [markdown]
# # calculate and plot the first derivative of the curve

# %%
# to see the differnece in infection rate

corona_dataset_aggregated.loc['China'].diff().plot()

# %%
# to calculate the maximum infection rate in china

corona_dataset_aggregated.loc['China'].diff().max() # the max people affected by corona in one day
# Out:
# 15136.0

# %%
# now lets calculate for india

corona_dataset_aggregated.loc['India'].diff().max() # the max people affected by corona in one day (india)
# Out:
# 1893.0

# %% [markdown]
# # Find the maximum infection rate for all countries

# %%
# loop through every country and find the max infection rate

max_infection_rate = [] # store the values pf max infection rate
countries = corona_dataset_aggregated.index

for country in countries:
    max_infection_rate.append(corona_dataset_aggregated.loc[country].diff().max())

# %%
# add the column to the dataframe named maximum infection rate

corona_dataset_aggregated['maximum infection rate'] = max_infection_rate

# %%
# view the added column at the end of dataframe

corona_dataset_aggregated
# Out:
#                     1/22/20  1/23/20  1/24/20  1/25/20  1/26/20  1/27/20  \
# Country/Region
# Afghanistan               0        0        0        0        0        0
# Albania                   0        0        0        0        0        0
# Algeria                   0        0        0        0        0        0
# Andorra                   0        0        0        0        0        0
# Angola                    0        0        0        0        0        0
# ...                     ...      ...      ...      ...      ...      ...
# West Bank and Gaza        0        0        0        0        0        0
# Western Sahara            0        0        0        0        0        0
# Yemen                     0        0        0        0        0        0
# Zambia                    0        0        0        0        0        0
# Zimbabwe                  0        0        0        0        0        0
#
# ...

# %% [markdown]
# # Create a new dataframe with needed columns

# %%
# to create a new dataframe we use DataFrame() method

corona_data = pd.DataFrame(corona_dataset_aggregated['maximum infection rate'])

# %%
# view the contents of dataframe

corona_data.head(10)
# Out:
#                      maximum infection rate
# Country/Region
# Afghanistan                           232.0
# Albania                                34.0
# Algeria                               199.0
# Andorra                                43.0
# Angola                                  5.0
# Antigua and Barbuda                     6.0
# Argentina                             291.0
# Armenia                               134.0
# Australia                             497.0
# Austria                              1321.0

# %% [markdown]
# ## Next task
#
# * Import the WorldHappinessReport.csv dataset
# * selecting needed columns for our analysis
# * join the datasets
# * calculate the correlations as the result of our analysis

# %%
# our dataset is -> worldwide_happiness_report.csv

world_happiness_report= pd.read_csv("worldwide_happiness_report.csv")
 
# view the dataframe

world_happiness_report.head(10)
# Out:
#    Overall rank Country or region  Score  GDP per capita  Social support  \
# 0             1           Finland  7.769           1.340           1.587
# 1             2           Denmark  7.600           1.383           1.573
# 2             3            Norway  7.554           1.488           1.582
# 3             4           Iceland  7.494           1.380           1.624
# 4             5       Netherlands  7.488           1.396           1.522
# 5             6       Switzerland  7.480           1.452           1.526
# 6             7            Sweden  7.343           1.387           1.487
# 7             8       New Zealand  7.307           1.303           1.557
# 8             9            Canada  7.278           1.365           1.505
# 9            10           Austria  7.246           1.376           1.475
#
#    Healthy life expectancy  Freedom to make life choices  Generosity  \
# 0                    0.986                         0.596       0.153
# ...

# %%
# view the dimensions of the dataset -> shape

world_happiness_report.shape
# Out:
# (156, 9)

# %% [markdown]
# # Drop  the useless columns

# %%
world_happiness_report.set_index(['Country or region'],inplace=True)

columns_to_dropped = ['Overall rank','Score','Generosity','Perceptions of corruption']

world_happiness_report.drop(columns_to_dropped, axis = 1, inplace = True)

# %%
# view the contents of df after dropping useless columns

world_happiness_report.head(10)
# Out:
#                    GDP per capita  Social support  Healthy life expectancy  \
# Country or region
# Finland                     1.340           1.587                    0.986
# Denmark                     1.383           1.573                    0.996
# Norway                      1.488           1.582                    1.028
# Iceland                     1.380           1.624                    1.026
# Netherlands                 1.396           1.522                    0.999
# Switzerland                 1.452           1.526                    1.052
# Sweden                      1.387           1.487                    1.009
# New Zealand                 1.303           1.557                    1.026
# Canada                      1.365           1.505                    1.039
# Austria                     1.376           1.475                    1.016
#
#                    Freedom to make life choices
# Country or region
# Finland                                   0.596
# ...

# %% [markdown]
# # Join The Two datasets

# %% [markdown]
# ### Coraona Dataset

# %%
corona_data
# Out:
#                     maximum infection rate
# Country/Region
# Afghanistan                          232.0
# Albania                               34.0
# Algeria                              199.0
# Andorra                               43.0
# Angola                                 5.0
# ...                                    ...
# West Bank and Gaza                    66.0
# Western Sahara                         4.0
# Yemen                                  5.0
# Zambia                                 9.0
# Zimbabwe                               8.0
#
# [187 rows x 1 columns]

# %% [markdown]
# # World happiness Dataset

# %%
world_happiness_report
# Out:
#                           GDP per capita  Social support  \
# Country or region
# Finland                            1.340           1.587
# Denmark                            1.383           1.573
# Norway                             1.488           1.582
# Iceland                            1.380           1.624
# Netherlands                        1.396           1.522
# ...                                  ...             ...
# Rwanda                             0.359           0.711
# Tanzania                           0.476           0.885
# Afghanistan                        0.350           0.517
# Central African Republic           0.026           0.000
# South Sudan                        0.306           0.575
#
#                           Healthy life expectancy  \
# Country or region
# Finland                                     0.986
# Denmark                                     0.996
# Norway                                      1.028
# ...

# %%
data = corona_data.join(world_happiness_report,how="inner")
data.head(10)
# Out:
#              maximum infection rate  GDP per capita  Social support  \
# Afghanistan                   232.0           0.350           0.517
# Albania                        34.0           0.947           0.848
# Algeria                       199.0           1.002           1.160
# Argentina                     291.0           1.092           1.432
# Armenia                       134.0           0.850           1.055
# Australia                     497.0           1.372           1.548
# Austria                      1321.0           1.376           1.475
# Azerbaijan                    105.0           1.043           1.147
# Bahrain                       301.0           1.362           1.368
# Bangladesh                    641.0           0.562           0.928
#
#              Healthy life expectancy  Freedom to make life choices
# Afghanistan                    0.361                         0.000
# Albania                        0.874                         0.383
# ...

# %% [markdown]
# ## Create the correlation matrix

# %%
# it is represents the currelation between every two columns of our dataset -> using corr() method

data.corr()
# Out:
#                               maximum infection rate  GDP per capita  \
# maximum infection rate                      1.000000        0.250118
# GDP per capita                              0.250118        1.000000
# Social support                              0.191958        0.759468
# Healthy life expectancy                     0.289263        0.863062
# Freedom to make life choices                0.078196        0.394603
#
#                               Social support  Healthy life expectancy  \
# maximum infection rate              0.191958                 0.289263
# GDP per capita                      0.759468                 0.863062
# Social support                      1.000000                 0.765286
# Healthy life expectancy             0.765286                 1.000000
# Freedom to make life choices        0.456246                 0.427892
#
#                               Freedom to make life choices
# maximum infection rate                            0.078196
# ...

# %% [markdown]
# # Visualization of the results

# %%
data.head(10)
# Out:
#              maximum infection rate  GDP per capita  Social support  \
# Afghanistan                   232.0           0.350           0.517
# Albania                        34.0           0.947           0.848
# Algeria                       199.0           1.002           1.160
# Argentina                     291.0           1.092           1.432
# Armenia                       134.0           0.850           1.055
# Australia                     497.0           1.372           1.548
# Austria                      1321.0           1.376           1.475
# Azerbaijan                    105.0           1.043           1.147
# Bahrain                       301.0           1.362           1.368
# Bangladesh                    641.0           0.562           0.928
#
#              Healthy life expectancy  Freedom to make life choices
# Afghanistan                    0.361                         0.000
# Albania                        0.874                         0.383
# ...

# %% [markdown]
# ### GDP vs Max infection rate

# %%
x = data['GDP per capita']
y = data['maximum infection rate']

sns.scatterplot(x, np.log(y))

# %%
sns.regplot(x,np.log(y))

# %% [markdown]
# ### Social support vs Max infection rate

# %%
x = data['Social support']
y = data['maximum infection rate']

sns.scatterplot(x,np.log(y))

# %%
sns.regplot(x,np.log(y))

# %%
x = data['Healthy life expectancy']
y = data['maximum infection rate']
sns.scatterplot(x,np.log(y))

# %%
sns.regplot(x,np.log(y))

# %% [markdown]
# ### Freedom of life choices vs max infection rate

# %%
x = data['Freedom to make life choices']
y = data['maximum infection rate']
sns.scatterplot(x,np.log(y))

# %%
sns.regplot(x,np.log(y))
